# %% [markdown]
# ## 6388040 Ariya Phengphon (Section 2)
# ### Lab 9 : The use of Python Library (Scikit-learn: Machine Learning in Python)

# %%
# Exercise 1) Check the important library and their versions
import sys
import scipy
import numpy
import matplotlib
import pandas
import sklearn

print('Python: {}'.format(sys.version))
print('scipy: {}'.format(scipy.__version__))
print('numpy: {}'.format(numpy.__version__))
print('matplotlib: {}'.format(matplotlib.__version__))
print('pandas: {}'.format(pandas.__version__))
print('sklearn: {}'.format(sklearn.__version__))
# Out:
# Python: 3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]
# scipy: 1.6.2
# numpy: 1.20.1
# matplotlib: 3.3.4
# pandas: 1.2.4
# sklearn: 0.24.1

# %%
# Exercise 2) Load all the important library
import pandas
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.neighbors import KNeighborsClassifier

# %%
# Exercise 3) Load the iris dataset from file (iris.data)
names = ['sepal - length', 'sepal - width', 'petal - length', 'petal - width', 'class'] # set the name of each column
ds = pandas.read_csv('iris.data', names = names) # read the dataset, and put name into each column
# display the dataset
ds
# Out:
#      sepal - length  sepal - width  petal - length  petal - width  \
# 0               5.1            3.5             1.4            0.2
# 1               4.9            3.0             1.4            0.2
# 2               4.7            3.2             1.3            0.2
# 3               4.6            3.1             1.5            0.2
# 4               5.0            3.6             1.4            0.2
# ..              ...            ...             ...            ...
# 145             6.7            3.0             5.2            2.3
# 146             6.3            2.5             5.0            1.9
# 147             6.5            3.0             5.2            2.0
# 148             6.2            3.4             5.4            2.3
# 149             5.9            3.0             5.1            1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# ...

# %%
# Exercise 4) Display basic information of this dataset
print(ds.shape)     # display rows x columns of the dataset
print(ds.head(20))  # print first 20 rows of the dataset
print(ds.describe())  # show number based on the statistic of the dataset (Ex: min, max)
print(ds.groupby('class').size()) # group all of the items on the dataset by using 'class' to seperate
# Out:
# (150, 5)
#     sepal - length  sepal - width  petal - length  petal - width        class
# 0              5.1            3.5             1.4            0.2  Iris-setosa
# 1              4.9            3.0             1.4            0.2  Iris-setosa
# 2              4.7            3.2             1.3            0.2  Iris-setosa
# 3              4.6            3.1             1.5            0.2  Iris-setosa
# 4              5.0            3.6             1.4            0.2  Iris-setosa
# 5              5.4            3.9             1.7            0.4  Iris-setosa
# 6              4.6            3.4             1.4            0.3  Iris-setosa
# 7              5.0            3.4             1.5            0.2  Iris-setosa
# 8              4.4            2.9             1.4            0.2  Iris-setosa
# 9              4.9            3.1             1.5            0.1  Iris-setosa
# 10             5.4            3.7             1.5            0.2  Iris-setosa
# ...

# %%
# Exercise 5) Create a box plots on iris dataset (Lesson from week 7)
ds.plot(kind = 'box', subplots = True, layout = (2,2), # layout = (width,height)
        sharex = False, sharey = False) # Controls sharing of properties among x (sharex) or y (sharey) axes:
plt.show()

# %% [markdown]
# --- Milestone 1 Completed ---

# %%
# Exercise 6) Seperate features of iris flower from the target
array = ds.values   # returns a list of all the values in the dataset
X = array[:,0:4]    # get all items (:), from columns 0-3 (feature)
Y = array[:,4]      # get all items, from column 4 (target)
print("X size:", X.size)
print("Y size:", Y.size)

print(X)
print(Y)
# Out:
# X size: 600
# Y size: 150
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.0 1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.0 3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.0 3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.0 1.4 0.1]
#  [4.3 3.0 1.1 0.1]
#  [5.8 4.0 1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.0 0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.0 3.0 1.6 0.2]
#  [5.0 3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.0 3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.1 1.5 0.1]
#  [4.4 3.0 1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.0 3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.0 3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.0 1.4 0.3]
# ...

# %%
# Exercise 7) Split iris.data into two groups (For training and testing)
test_size = 0.20
seed = 7
X_train , X_test , Y_train , Y_test = model_selection.train_test_split(X, Y, test_size = test_size, random_state = seed)
# used to split the dataset,
# based on test_size(size of the testing dataset) and
# random_state(Split by using seed's size, if not it's going to random split by using np.random)
print("X_train_size:", X_train.size)
print("X_test_size:", X_test.size)
print("Y_train_size:", Y_train.size)
print("Y_test_size:", Y_test.size)

print("X_train:\n", X_train)
print("X_test:\n", X_test)
print("Y_train:\n", Y_train)
print("Y_test:\n", Y_test)
# Out:
# X_train_size: 480
# X_test_size: 120
# Y_train_size: 120
# Y_test_size: 30
# X_train:
#  [[6.2 2.8 4.8 1.8]
#  [5.7 2.6 3.5 1.0]
#  [4.6 3.6 1.0 0.2]
#  [6.9 3.1 5.4 2.1]
#  [6.4 2.9 4.3 1.3]
#  [4.8 3.0 1.4 0.3]
#  [5.5 3.5 1.3 0.2]
#  [5.4 3.9 1.7 0.4]
#  [5.1 3.5 1.4 0.3]
#  [7.1 3.0 5.9 2.1]
#  [6.7 3.3 5.7 2.1]
#  [6.8 2.8 4.8 1.4]
#  [6.4 2.8 5.6 2.2]
#  [6.5 3.0 5.5 1.8]
#  [5.7 3.0 4.2 1.2]
#  [5.0 3.3 1.4 0.2]
#  [6.7 3.1 4.4 1.4]
#  [6.0 2.2 4.0 1.0]
#  [6.4 2.7 5.3 1.9]
#  [4.7 3.2 1.6 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.1 3.4 1.5 0.2]
#  [7.7 3.8 6.7 2.2]
#  [4.3 3.0 1.1 0.1]
#  [6.3 3.3 6.0 2.5]
#  [5.5 2.4 3.7 1.0]
#  [5.0 2.0 3.5 1.0]
#  [6.5 2.8 4.6 1.5]
#  [5.0 3.4 1.6 0.4]
#  [4.4 2.9 1.4 0.2]
#  [5.0 3.5 1.6 0.6]
#  [6.7 3.1 4.7 1.5]
#  [7.3 2.9 6.3 1.8]
#  [5.5 2.6 4.4 1.2]
#  [5.2 2.7 3.9 1.4]
#  [5.7 4.4 1.5 0.4]
#  [7.2 3.2 6.0 1.8]
#  [5.4 3.4 1.7 0.2]
#  [5.8 4.0 1.2 0.2]
#  [6.1 2.6 5.6 1.4]
#  [5.7 2.5 5.0 2.0]
#  [4.8 3.0 1.4 0.1]
#  [6.5 3.0 5.8 2.2]
# ...

# %%
# Exercise 8) Change num 7
test_size = 0.5
seed = 10
X_train , X_test , Y_train , Y_test = model_selection.train_test_split(X, Y, test_size = test_size, random_state = seed)
# used to split the dataset, based on
# test_size(size of the testing dataset)
# and random_state(Split by using seed's size(seed of data), if not it's going to random split by using np.random)
print("X_train_size:", X_train.size)
print("X_test_size:", X_test.size)
print("Y_train_size:", Y_train.size)
print("Y_test_size:", Y_test.size)

print("X_train:\n", X_train)
print("X_test:\n", X_test)
print("Y_train:\n", Y_train)
print("Y_test:\n", Y_test)
# Out:
# X_train_size: 300
# X_test_size: 300
# Y_train_size: 75
# Y_test_size: 75
# X_train:
#  [[6.3 2.8 5.1 1.5]
#  [4.6 3.4 1.4 0.3]
#  [5.7 2.6 3.5 1.0]
#  [6.7 2.5 5.8 1.8]
#  [5.7 2.8 4.1 1.3]
#  [4.9 3.1 1.5 0.1]
#  [6.4 2.8 5.6 2.1]
#  [7.0 3.2 4.7 1.4]
#  [5.7 2.9 4.2 1.3]
#  [5.0 3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [5.1 3.8 1.9 0.4]
#  [5.4 3.0 4.5 1.5]
#  [7.4 2.8 6.1 1.9]
#  [6.3 2.9 5.6 1.8]
#  [6.6 3.0 4.4 1.4]
#  [5.0 3.4 1.5 0.2]
#  [5.1 3.8 1.6 0.2]
#  [5.1 3.5 1.4 0.3]
#  [6.5 3.0 5.8 2.2]
#  [5.8 2.7 5.1 1.9]
#  [6.1 2.8 4.0 1.3]
#  [5.5 2.4 3.8 1.1]
#  [6.5 3.2 5.1 2.0]
#  [6.5 3.0 5.2 2.0]
#  [5.9 3.0 5.1 1.8]
#  [6.1 2.6 5.6 1.4]
#  [6.4 2.9 4.3 1.3]
#  [5.2 3.4 1.4 0.2]
#  [4.8 3.4 1.6 0.2]
#  [5.6 2.7 4.2 1.3]
#  [5.1 3.3 1.7 0.5]
#  [4.6 3.6 1.0 0.2]
#  [6.1 3.0 4.9 1.8]
#  [5.0 2.3 3.3 1.0]
#  [5.7 3.8 1.7 0.3]
#  [5.2 3.5 1.5 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 2.4 3.3 1.0]
#  [5.4 3.4 1.5 0.4]
#  [6.7 3.1 4.4 1.4]
#  [4.8 3.0 1.4 0.1]
#  [5.5 2.5 4.0 1.3]
# ...

# %% [markdown]
# ### __K-nearest neighbors(KNN)__ is a type of supervised learning algorithm used for both regression and classification. KNN tries to predict the correct class for the test data by calculating the distance between the test data and all the training points.

# %% [markdown]
# Exercise 9) The K-nearest Neighbors state that the new object will be classified to the majority vote of it k-nearest neighbors. Hence, if we considered
# k=1 and k=3 as presented in Figure 3, what did you see?
# What would be the output after classification? Which one is more reliable
# between setting k=1 or k=3? Should k be Odd or Even number? Why?
#
# __ANS:__ I think ```k=3``` is more reliable, since the finding range is bigger and as of the result it makes the test data matches with the catagories that it should be/looks like the most.
# Maybe ```Odd number``` is better because in case that the training point of each catagories are equal, it would effect the final result. (like k = 8, there are two categories: A = 4, B = 4, then the final result has two values which are A and B)

# %%
# Exercise 10) Using K-nearest neighbors technique, now use 7 neighbors
irisML = KNeighborsClassifier(n_neighbors = 7)
irisML.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %% [markdown]
# --- Milestone 2 Completed ---

# %%
# Exercise 11) Pass the test dataset to the model for the prediction
prediction = irisML.predict(X_test)
print(prediction) #.predict(): predict the labels of the data values on the basis of the trained model
print(prediction.size)
# Out:
# ['Iris-versicolor' 'Iris-virginica']
# 2

# %%
# Exercise 12) To see the score of prediction model
prediction = irisML.score(X_test, Y_test)
print(prediction) # .score(): the method computes the accuracy score by default of the model
# Out:
# 0.9333333333333333

# %%
# Exercise 13) Input new iris object to the model to classify its specie
new_obj1 = [[5.2 ,4.3 ,5.6 ,1.6]]
output1 = irisML.predict(new_obj1)
print(output1)

new_obj2 = [[3.2, 4.1, 2.1, 1.0]]
output2 = irisML.predict(new_obj2)
print(output2)
# Out:
# ['Iris-virginica']
# ['Iris-setosa']

# %% [markdown]
# --- Milestone 3 Completed ---
