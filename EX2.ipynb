# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# CS159 Python

# %%
# %%latex
# \begin{align}
# y(x) = x^2 + 3x + 5
# \end{align}
# Out:
# \begin{align}
# y(x) = x^2 + 3x + 5
# \end{align}

# %% [markdown]
# Latex

# %%
# %%latex
# \begin{align}
# \lim\limits_ {n \to 100} x^n
# \end{align}
# Out:
# \begin{align}
# \lim\limits_ {n \to 100} x^n
# \end{align}

# %%
print("Hello World")
# Out:
# Hello World

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(999)
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(999)
N = 80
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/
plotly/datasets/master/school_earnings.csv")
        df
# Out:
#   File "<ipython-input-27-2de2d75687f2>", line 2
#     df = pd.read_csv("https://raw.githubusercontent.com/
#                                                         ^
# SyntaxError: EOL while scanning string literal

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")

# %%
df
# Out:
#         School  Women  Men  Gap
# 0          MIT     94  152   58
# 1     Stanford     96  151   55
# 2      Harvard    112  165   53
# 3       U.Penn     92  141   49
# 4    Princeton     90  137   47
# 5      Chicago     78  118   40
# 6   Georgetown     94  131   37
# 7        Tufts     76  112   36
# 8         Yale     79  114   35
# 9     Columbia     86  119   33
# 10        Duke     93  124   31
# 11   Dartmouth     84  114   30
# 12         NYU     67   94   27
# 13  Notre Dame     73  100   27
# 14     Cornell     80  107   27
# 15    Michigan     62   84   22
# 16       Brown     72   92   20
# 17    Berkeley     71   88   17
# 18       Emory     68   82   14
# 19        UCLA     64   78   14
# 20       SoCal     72   81    9

# %%
print(df)
# Out:
#         School  Women  Men  Gap
# 0          MIT     94  152   58
# 1     Stanford     96  151   55
# 2      Harvard    112  165   53
# 3       U.Penn     92  141   49
# 4    Princeton     90  137   47
# 5      Chicago     78  118   40
# 6   Georgetown     94  131   37
# 7        Tufts     76  112   36
# 8         Yale     79  114   35
# 9     Columbia     86  119   33
# 10        Duke     93  124   31
# 11   Dartmouth     84  114   30
# 12         NYU     67   94   27
# 13  Notre Dame     73  100   27
# 14     Cornell     80  107   27
# 15    Michigan     62   84   22
# 16       Brown     72   92   20
# 17    Berkeley     71   88   17
# 18       Emory     68   82   14
# 19        UCLA     64   78   14
# 20       SoCal     72   81    9

# %% [markdown]
# ## Faculty of Information and Communication Technology

# %% [markdown]
# We are studying ITCS159

# %% [markdown]
# **Software Lab for Basic Scientific Problem Solving**

# %% [markdown]
# Markdown can also create lists, for example

# %% [markdown]
# * first
# * second
# * third

# %% [markdown]
# Markdown can also create inline code, for example

# %% [markdown]
# ```
# Sayyy, Say!!!, Say Ouu, Say Ahh, Say ICT
# ```

# %%
# %%latex
# \begin{align}
# B'&=-\nabla \times E,\\
# E'&=\nabla \times B - 4\pi j, \\
# x &= \frac{-b\pm\sqrt{b^2-4ac}}{2a}
# \end{align}
# Out:
# \begin{align}
# B'&=-\nabla \times E,\\
# E'&=\nabla \times B - 4\pi j, \\
# x &= \frac{-b\pm\sqrt{b^2-4ac}}{2a}
# \end{align}

# %%
# %%latex
# \begin{align}
# f' (a) = \lim\limits_ {h \to 0} \frac{f(a+h)-f(a)}{h}
# \end{align}
# Out:
# \begin{align}
# f' (a) = \lim\limits_ {h \to 0} \frac{f(a+h)-f(a)}{h}
# \end{align}

# %%
# %%latex
# \begin{align}
# y = x + 1
# \end{align}
# Out:
# \begin{align}
# y = x + 1
# \end{align}

# %%
# %%latex
# \begin{align}
# f' (a) = \lim\limits_ {h \to 0} \frac{f(a+h)-f(a)}{h(y)}
# \end{align}
# Out:
# \begin{align}
# f' (a) = \lim\limits_ {h \to 0} \frac{f(a+h)-f(a)}{h(y)}
# \end{align}
